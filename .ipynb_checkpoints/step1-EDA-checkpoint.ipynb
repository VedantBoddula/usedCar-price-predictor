# %% [markdown]
# # step 1- EDA

# %%
import pandas as pd

# %%
data = pd.read_csv("used_car_price_dataset_extended.csv")

# %%
data.head()
# Out:
#    make_year  mileage_kmpl  engine_cc fuel_type  owner_count  price_usd  \
# 0       2001          8.17       4000    Petrol            4    8587.64
# 1       2014         17.59       1500    Petrol            4    5943.50
# 2       2023         18.09       2500    Diesel            5    9273.58
# 3       2009         11.28        800    Petrol            1    6836.24
# 4       2005         12.23       1000    Petrol            2    4625.79
#
#        brand transmission  color service_history  accidents_reported  \
# 0  Chevrolet       Manual  White             NaN                   0
# 1      Honda       Manual  Black             NaN                   0
# 2        BMW    Automatic  Black            Full                   1
# 3    Hyundai       Manual   Blue            Full                   0
# 4     Nissan    Automatic    Red            Full                   0
#
#   insurance_valid
# 0              No
# 1             Yes
# 2             Yes
# 3             Yes
# 4             Yes

# %%
data.tail()
# Out:
#       make_year  mileage_kmpl  engine_cc fuel_type  owner_count  price_usd  \
# 9995       1996         15.25       1500    Petrol            2    5498.71
# 9996       1997         14.45       5000    Diesel            1    9588.31
# 9997       2002         19.41       1000    Diesel            4    4557.10
# 9998       2005         12.95       4000    Petrol            5    7413.59
# 9999       2007         18.81       5000    Petrol            1   11634.09
#
#         brand transmission   color service_history  accidents_reported  \
# 9995  Hyundai       Manual  Silver             NaN                   0
# 9996    Honda       Manual    Gray            Full                   0
# 9997      Kia       Manual   Black            Full                   0
# 9998      BMW    Automatic    Blue            Full                   0
# 9999      BMW    Automatic  Silver            Full                   0
#
#      insurance_valid
# 9995             Yes
# 9996             Yes
# 9997             Yes
# 9998             Yes
# 9999             Yes

# %%
data.describe()
# Out:
#           make_year  mileage_kmpl     engine_cc   owner_count     price_usd  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    2009.206900     17.960753   2287.130000      3.003500   7179.754532
# std        8.373858      5.025486   1291.276927      1.418904   2795.270940
# min     1995.000000      5.000000    800.000000      1.000000   1000.000000
# 25%     2002.000000     14.540000   1200.000000      2.000000   5176.547500
# 50%     2009.000000     17.970000   1800.000000      3.000000   6961.260000
# 75%     2016.000000     21.352500   3000.000000      4.000000   8993.732500
# max     2023.000000     35.000000   5000.000000      5.000000  17647.630000
#
#        accidents_reported
# count        10000.000000
# mean             0.492200
# std              0.694109
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              1.000000
# max              5.000000

# %%
print(data.isnull().sum())
# Out:
# make_year                0
# mileage_kmpl             0
# engine_cc                0
# fuel_type                0
# owner_count              0
# price_usd                0
# brand                    0
# transmission             0
# color                    0
# service_history       2038
# accidents_reported       0
# insurance_valid          0
# dtype: int64

# %%
corr_matrix = data.corr(numeric_only=True)

print(corr_matrix["price_usd"].sort_values(ascending=False))
# Out:
# price_usd             1.000000
# engine_cc             0.678161
# make_year             0.432603
# mileage_kmpl          0.211971
# accidents_reported   -0.001461
# owner_count          -0.262266
# Name: price_usd, dtype: float64

# %%
data.columns
# Out:
# Index(['make_year', 'mileage_kmpl', 'engine_cc', 'fuel_type', 'owner_count',
#        'price_usd', 'brand', 'transmission', 'color', 'service_history',
#        'accidents_reported', 'insurance_valid'],
#       dtype='object')

# %%
dataFeatures = data.drop("price_usd", axis=1)

# %%
dataLabels = data["price_usd"]

# %%
dataFeatures.head()
# Out:
#    make_year  mileage_kmpl  engine_cc fuel_type  owner_count      brand  \
# 0       2001          8.17       4000    Petrol            4  Chevrolet
# 1       2014         17.59       1500    Petrol            4      Honda
# 2       2023         18.09       2500    Diesel            5        BMW
# 3       2009         11.28        800    Petrol            1    Hyundai
# 4       2005         12.23       1000    Petrol            2     Nissan
#
#   transmission  color service_history  accidents_reported insurance_valid
# 0       Manual  White             NaN                   0              No
# 1       Manual  Black             NaN                   0             Yes
# 2    Automatic  Black            Full                   1             Yes
# 3       Manual   Blue            Full                   0             Yes
# 4    Automatic    Red            Full                   0             Yes

# %%
dataLabels.head()
# Out:
# 0    8587.64
# 1    5943.50
# 2    9273.58
# 3    6836.24
# 4    4625.79
# Name: price_usd, dtype: float64

# %% [markdown]
# #  step 2-Split into training and test sets

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    dataFeatures,
    dataLabels,
    test_size=0.2,
    random_state=42
)

# %%
# X_train → 80% of the FEATURES
# y_train → 80% of the LABELS

# X_test  → 20% of the FEATURES
# y_test  → 20% of the LABELS

#During Training model.fit(X_train, y_train)

#During testing predictions = model.predict(X_test)

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
# Out:
# X_train shape: (8000, 11)
# X_test shape: (2000, 11)

# %%
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# y_train shape: (8000,)
# y_test shape: (2000,)

# %%
num_attributes = X_train.select_dtypes(include=["int64","float64"]).columns.tolist()

# %%
cat_attributes = X_train.select_dtypes(include=["object"]).columns.tolist

# %%
num_attributes
# Out:
# ['make_year', 'mileage_kmpl', 'engine_cc', 'owner_count', 'accidents_reported']

# %%
cat_attributes
# Out:
# <bound method IndexOpsMixin.tolist of Index(['fuel_type', 'brand', 'transmission', 'color', 'service_history',
#        'insurance_valid'],
#       dtype='object')>
